# %% [markdown]
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN on augmented images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
y_valid = keras.utils.to_categorical(y_valid, num_classes)

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# ('x_train shape:', (45000, 32, 32, 3))
# (45000, 'train samples')
# (10000, 'test samples')
# (5000, 'validation samples')

# %% [markdown]
# ### 5. Create and Configure Augmented Image Generator

# %%
from keras.preprocessing.image import ImageDataGenerator

# create and configure augmented image generator
datagen_train = ImageDataGenerator(
    width_shift_range=0.1,  # randomly shift images horizontally (10% of total width)
    height_shift_range=0.1,  # randomly shift images vertically (10% of total height)
    horizontal_flip=True) # randomly flip images horizontally

# create and configure augmented image generator
datagen_valid = ImageDataGenerator(
    width_shift_range=0.1,  # randomly shift images horizontally (10% of total width)
    height_shift_range=0.1,  # randomly shift images vertically (10% of total height)
    horizontal_flip=True) # randomly flip images horizontally

# fit augmented image generator on data
datagen_train.fit(x_train)
datagen_valid.fit(x_valid)

# %% [markdown]
# ### 6. Visualize Original and Augmented Images

# %%
import matplotlib.pyplot as plt

# take subset of training data
x_train_subset = x_train[:12]

# visualize subset of training data
fig = plt.figure(figsize=(20,2))
for i in range(0, len(x_train_subset)):
    ax = fig.add_subplot(1, 12, i+1)
    ax.imshow(x_train_subset[i])
fig.suptitle('Subset of Original Training Images', fontsize=20)
plt.show()

# visualize augmented images
fig = plt.figure(figsize=(20,2))
for x_batch in datagen_train.flow(x_train_subset, batch_size=12):
    for i in range(0, 12):
        ax = fig.add_subplot(1, 12, i+1)
        ax.imshow(x_batch[i])
    fig.suptitle('Augmented Images', fontsize=20)
    plt.show()
    break;

# %% [markdown]
# ### 7. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        208
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               512500
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 528,054
# Trainable params: 528,054
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 8. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 9. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

batch_size = 32
epochs = 100

# train the model
checkpointer = ModelCheckpoint(filepath='aug_model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
model.fit_generator(datagen_train.flow(x_train, y_train, batch_size=batch_size),
                    steps_per_epoch=x_train.shape[0] // batch_size,
                    epochs=epochs, verbose=2, callbacks=[checkpointer],
                    validation_data=datagen_valid.flow(x_valid, y_valid, batch_size=batch_size),
                    validation_steps=x_valid.shape[0] // batch_size)
# Out:
# Epoch 1/100
#  - 30s - loss: 1.6566 - accuracy: 0.3952 - val_loss: 1.5556 - val_accuracy: 0.4866
#
# Epoch 00001: val_loss improved from inf to 1.55560, saving model to aug_model.weights.best.hdf5
# Epoch 2/100
#  - 33s - loss: 1.3877 - accuracy: 0.5007 - val_loss: 1.2091 - val_accuracy: 0.5598
#
# Epoch 00002: val_loss improved from 1.55560 to 1.20914, saving model to aug_model.weights.best.hdf5
# Epoch 3/100
#  - 29s - loss: 1.2744 - accuracy: 0.5465 - val_loss: 1.1496 - val_accuracy: 0.5640
#
# Epoch 00003: val_loss improved from 1.20914 to 1.14962, saving model to aug_model.weights.best.hdf5
# Epoch 4/100
#  - 30s - loss: 1.2105 - accuracy: 0.5719 - val_loss: 1.2121 - val_accuracy: 0.6226
#
# Epoch 00004: val_loss did not improve from 1.14962
# Epoch 5/100
#  - 32s - loss: 1.1799 - accuracy: 0.5847 - val_loss: 1.5049 - val_accuracy: 0.6381
#
# Epoch 00005: val_loss did not improve from 1.14962
# Epoch 6/100
#  - 32s - loss: 1.1674 - accuracy: 0.5920 - val_loss: 1.1641 - val_accuracy: 0.6375
#
# Epoch 00006: val_loss did not improve from 1.14962
# Epoch 7/100
#  - 33s - loss: 1.1548 - accuracy: 0.5974 - val_loss: 1.2693 - val_accuracy: 0.6439
#
# Epoch 00007: val_loss did not improve from 1.14962
# Epoch 8/100
#  - 34s - loss: 1.1451 - accuracy: 0.6040 - val_loss: 0.8776 - val_accuracy: 0.6300
#
# Epoch 00008: val_loss improved from 1.14962 to 0.87759, saving model to aug_model.weights.best.hdf5
# Epoch 9/100
#  - 47s - loss: 1.1479 - accuracy: 0.6034 - val_loss: 1.3831 - val_accuracy: 0.6294
#
# Epoch 00009: val_loss did not improve from 0.87759
# Epoch 10/100
#  - 42s - loss: 1.1437 - accuracy: 0.6054 - val_loss: 1.1716 - val_accuracy: 0.6290
#
# Epoch 00010: val_loss did not improve from 0.87759
# Epoch 11/100
#  - 39s - loss: 1.1607 - accuracy: 0.6027 - val_loss: 1.1377 - val_accuracy: 0.6530
#
# Epoch 00011: val_loss did not improve from 0.87759
# Epoch 12/100
#  - 37s - loss: 1.1723 - accuracy: 0.6012 - val_loss: 0.9791 - val_accuracy: 0.6111
#
# Epoch 00012: val_loss did not improve from 0.87759
# Epoch 13/100
#  - 37s - loss: 1.1880 - accuracy: 0.5950 - val_loss: 0.9656 - val_accuracy: 0.6419
#
# Epoch 00013: val_loss did not improve from 0.87759
# Epoch 14/100
#  - 33s - loss: 1.2077 - accuracy: 0.5910 - val_loss: 1.1877 - val_accuracy: 0.6586
#
# Epoch 00014: val_loss did not improve from 0.87759
# Epoch 15/100
#  - 29s - loss: 1.2263 - accuracy: 0.5842 - val_loss: 1.3922 - val_accuracy: 0.6391
#
# Epoch 00015: val_loss did not improve from 0.87759
# Epoch 16/100
#  - 38s - loss: 1.2308 - accuracy: 0.5807 - val_loss: 0.8077 - val_accuracy: 0.6439
#
# Epoch 00016: val_loss improved from 0.87759 to 0.80773, saving model to aug_model.weights.best.hdf5
# Epoch 17/100
#  - 33s - loss: 1.2399 - accuracy: 0.5806 - val_loss: 0.8233 - val_accuracy: 0.6439
#
# Epoch 00017: val_loss did not improve from 0.80773
# Epoch 18/100
#  - 35s - loss: 1.2620 - accuracy: 0.5694 - val_loss: 1.2677 - val_accuracy: 0.6355
#
# Epoch 00018: val_loss did not improve from 0.80773
# Epoch 19/100
#  - 33s - loss: 1.2752 - accuracy: 0.5671 - val_loss: 0.9561 - val_accuracy: 0.6445
#
# Epoch 00019: val_loss did not improve from 0.80773
# Epoch 20/100
#  - 30s - loss: 1.2745 - accuracy: 0.5687 - val_loss: 1.5489 - val_accuracy: 0.5878
#
# Epoch 00020: val_loss did not improve from 0.80773
# Epoch 21/100
#  - 30s - loss: 1.3033 - accuracy: 0.5568 - val_loss: 0.7424 - val_accuracy: 0.6246
#
# Epoch 00021: val_loss improved from 0.80773 to 0.74236, saving model to aug_model.weights.best.hdf5
# Epoch 22/100
#  - 31s - loss: 1.3046 - accuracy: 0.5571 - val_loss: 1.1668 - val_accuracy: 0.5362
#
# Epoch 00022: val_loss did not improve from 0.74236
# Epoch 23/100
#  - 31s - loss: 1.3235 - accuracy: 0.5536 - val_loss: 1.0984 - val_accuracy: 0.5976
#
# Epoch 00023: val_loss did not improve from 0.74236
# Epoch 24/100
#  - 33s - loss: 1.3420 - accuracy: 0.5466 - val_loss: 1.4677 - val_accuracy: 0.6019
#
# Epoch 00024: val_loss did not improve from 0.74236
# Epoch 25/100
#  - 29s - loss: 1.3476 - accuracy: 0.5457 - val_loss: 1.2138 - val_accuracy: 0.6095
#
# Epoch 00025: val_loss did not improve from 0.74236
# Epoch 26/100
#  - 29s - loss: 1.3674 - accuracy: 0.5391 - val_loss: 0.8891 - val_accuracy: 0.6047
#
# Epoch 00026: val_loss did not improve from 0.74236
# Epoch 27/100
#  - 28s - loss: 1.3808 - accuracy: 0.5331 - val_loss: 0.7153 - val_accuracy: 0.6135
#
# Epoch 00027: val_loss improved from 0.74236 to 0.71527, saving model to aug_model.weights.best.hdf5
# Epoch 28/100
#  - 39s - loss: 1.3899 - accuracy: 0.5331 - val_loss: 1.5338 - val_accuracy: 0.5288
#
# Epoch 00028: val_loss did not improve from 0.71527
# Epoch 29/100
#  - 31s - loss: 1.3965 - accuracy: 0.5279 - val_loss: 1.1034 - val_accuracy: 0.5161
#
# Epoch 00029: val_loss did not improve from 0.71527
# Epoch 30/100
#  - 28s - loss: 1.4066 - accuracy: 0.5251 - val_loss: 1.2509 - val_accuracy: 0.5636
#
# Epoch 00030: val_loss did not improve from 0.71527
# Epoch 31/100
#  - 28s - loss: 1.4110 - accuracy: 0.5239 - val_loss: 1.6395 - val_accuracy: 0.5511
#
# Epoch 00031: val_loss did not improve from 0.71527
# Epoch 32/100
#  - 29s - loss: 1.4318 - accuracy: 0.5200 - val_loss: 1.5475 - val_accuracy: 0.5612
#
# Epoch 00032: val_loss did not improve from 0.71527
# Epoch 33/100
#  - 28s - loss: 1.4367 - accuracy: 0.5116 - val_loss: 1.1021 - val_accuracy: 0.5501
#
# Epoch 00033: val_loss did not improve from 0.71527
# Epoch 34/100
#  - 28s - loss: 1.4507 - accuracy: 0.5059 - val_loss: 1.2861 - val_accuracy: 0.5964
#
# Epoch 00034: val_loss did not improve from 0.71527
# Epoch 35/100
#  - 28s - loss: 1.4651 - accuracy: 0.5020 - val_loss: 1.3744 - val_accuracy: 0.5507
#
# Epoch 00035: val_loss did not improve from 0.71527
# Epoch 36/100
#  - 28s - loss: 1.4838 - accuracy: 0.5006 - val_loss: 1.6664 - val_accuracy: 0.5803
#
# Epoch 00036: val_loss did not improve from 0.71527
# Epoch 37/100
#  - 36s - loss: 1.4847 - accuracy: 0.4939 - val_loss: 1.4204 - val_accuracy: 0.5433
#
# Epoch 00037: val_loss did not improve from 0.71527
# Epoch 38/100
#  - 31s - loss: 1.4977 - accuracy: 0.4915 - val_loss: 1.2936 - val_accuracy: 0.5962
#
# Epoch 00038: val_loss did not improve from 0.71527
# Epoch 39/100
#  - 32s - loss: 1.5056 - accuracy: 0.4889 - val_loss: 1.4244 - val_accuracy: 0.4519
#
# Epoch 00039: val_loss did not improve from 0.71527
# Epoch 40/100
#  - 34s - loss: 1.5098 - accuracy: 0.4843 - val_loss: 1.4839 - val_accuracy: 0.5562
#
# Epoch 00040: val_loss did not improve from 0.71527
# Epoch 41/100
#  - 36s - loss: 1.5257 - accuracy: 0.4818 - val_loss: 1.6075 - val_accuracy: 0.5707
#
# Epoch 00041: val_loss did not improve from 0.71527
# Epoch 42/100
#  - 33s - loss: 1.5275 - accuracy: 0.4757 - val_loss: 1.3706 - val_accuracy: 0.5497
#
# Epoch 00042: val_loss did not improve from 0.71527
# Epoch 43/100
#  - 32s - loss: 1.5476 - accuracy: 0.4717 - val_loss: 1.4025 - val_accuracy: 0.5368
#
# Epoch 00043: val_loss did not improve from 0.71527
# Epoch 44/100
#  - 31s - loss: 1.5458 - accuracy: 0.4726 - val_loss: 1.3649 - val_accuracy: 0.5707
#
# Epoch 00044: val_loss did not improve from 0.71527
# Epoch 45/100
#  - 31s - loss: 1.5642 - accuracy: 0.4612 - val_loss: 1.3505 - val_accuracy: 0.5548
#
# Epoch 00045: val_loss did not improve from 0.71527
# Epoch 46/100
#  - 35s - loss: 1.5628 - accuracy: 0.4682 - val_loss: 1.3470 - val_accuracy: 0.4463
#
# Epoch 00046: val_loss did not improve from 0.71527
# Epoch 47/100
#  - 35s - loss: 1.5783 - accuracy: 0.4610 - val_loss: 1.3297 - val_accuracy: 0.4738
#
# Epoch 00047: val_loss did not improve from 0.71527
# Epoch 48/100
#  - 33s - loss: 1.5808 - accuracy: 0.4552 - val_loss: 1.1221 - val_accuracy: 0.5431
#
# Epoch 00048: val_loss did not improve from 0.71527
# Epoch 49/100
#  - 36s - loss: 1.5840 - accuracy: 0.4560 - val_loss: 1.4564 - val_accuracy: 0.4863
#
# Epoch 00049: val_loss did not improve from 0.71527
# Epoch 50/100
#  - 33s - loss: 1.6018 - accuracy: 0.4558 - val_loss: 1.5986 - val_accuracy: 0.5141
#
# Epoch 00050: val_loss did not improve from 0.71527
# Epoch 51/100
#  - 36s - loss: 1.6084 - accuracy: 0.4501 - val_loss: 1.3990 - val_accuracy: 0.4833
#
# Epoch 00051: val_loss did not improve from 0.71527
# Epoch 52/100
#  - 34s - loss: 1.6380 - accuracy: 0.4399 - val_loss: 1.1344 - val_accuracy: 0.5123
#
# Epoch 00052: val_loss did not improve from 0.71527
# Epoch 53/100
#  - 35s - loss: 1.6395 - accuracy: 0.4350 - val_loss: 2.1136 - val_accuracy: 0.5477
#
# Epoch 00053: val_loss did not improve from 0.71527
# Epoch 54/100
#  - 32s - loss: 1.6375 - accuracy: 0.4338 - val_loss: 1.3645 - val_accuracy: 0.4746
# Epoch 00054: val_loss did not improve from 0.71527
# Epoch 55/100
#  - 36s - loss: 1.6474 - accuracy: 0.4287 - val_loss: 1.8101 - val_accuracy: 0.4716
#
# Epoch 00055: val_loss did not improve from 0.71527
# Epoch 56/100
#  - 34s - loss: 1.6737 - accuracy: 0.4260 - val_loss: 1.0562 - val_accuracy: 0.4968
#
# Epoch 00056: val_loss did not improve from 0.71527
# Epoch 57/100
#  - 32s - loss: 1.6692 - accuracy: 0.4228 - val_loss: 1.6330 - val_accuracy: 0.4714
#
# Epoch 00057: val_loss did not improve from 0.71527
# Epoch 58/100
#  - 33s - loss: 1.6815 - accuracy: 0.4170 - val_loss: 1.4801 - val_accuracy: 0.5163
#
# Epoch 00058: val_loss did not improve from 0.71527
# Epoch 59/100
#  - 35s - loss: 1.6808 - accuracy: 0.4190 - val_loss: 1.1729 - val_accuracy: 0.5133
#
# Epoch 00059: val_loss did not improve from 0.71527
# Epoch 60/100
#  - 32s - loss: 1.6801 - accuracy: 0.4157 - val_loss: 1.5583 - val_accuracy: 0.4849
#
# Epoch 00060: val_loss did not improve from 0.71527
# Epoch 61/100
#  - 32s - loss: 1.7077 - accuracy: 0.4078 - val_loss: 1.7231 - val_accuracy: 0.4072
#
# Epoch 00061: val_loss did not improve from 0.71527
# Epoch 62/100
#  - 32s - loss: 1.7058 - accuracy: 0.4048 - val_loss: 1.5224 - val_accuracy: 0.5006
#
# Epoch 00062: val_loss did not improve from 0.71527
# Epoch 63/100
#  - 33s - loss: 1.7283 - accuracy: 0.4022 - val_loss: 1.5797 - val_accuracy: 0.4006
#
# Epoch 00063: val_loss did not improve from 0.71527
# Epoch 64/100
#  - 32s - loss: 1.7103 - accuracy: 0.4009 - val_loss: 1.5470 - val_accuracy: 0.4994
#
# Epoch 00064: val_loss did not improve from 0.71527
# Epoch 65/100
#  - 36s - loss: 1.7254 - accuracy: 0.3963 - val_loss: 1.5119 - val_accuracy: 0.4676
#
# Epoch 00065: val_loss did not improve from 0.71527
# Epoch 66/100
#  - 37s - loss: 1.7434 - accuracy: 0.3865 - val_loss: 1.5147 - val_accuracy: 0.4404
#
# Epoch 00066: val_loss did not improve from 0.71527
# Epoch 67/100
#  - 33s - loss: 1.7540 - accuracy: 0.3836 - val_loss: 1.5044 - val_accuracy: 0.4511
#
# Epoch 00067: val_loss did not improve from 0.71527
# Epoch 68/100
#  - 32s - loss: 1.7591 - accuracy: 0.3857 - val_loss: 1.6025 - val_accuracy: 0.4430
#
# Epoch 00068: val_loss did not improve from 0.71527
# Epoch 69/100
#  - 36s - loss: 1.7528 - accuracy: 0.3862 - val_loss: 1.3522 - val_accuracy: 0.4521
#
# Epoch 00069: val_loss did not improve from 0.71527
# Epoch 70/100
#  - 34s - loss: 1.7572 - accuracy: 0.3788 - val_loss: 1.3112 - val_accuracy: 0.4767
#
# Epoch 00070: val_loss did not improve from 0.71527
# Epoch 71/100
#  - 32s - loss: 1.7607 - accuracy: 0.3780 - val_loss: 1.4304 - val_accuracy: 0.4312
#
# Epoch 00071: val_loss did not improve from 0.71527
# Epoch 72/100
#  - 33s - loss: 1.7601 - accuracy: 0.3793 - val_loss: 1.4646 - val_accuracy: 0.4253
#
# Epoch 00072: val_loss did not improve from 0.71527
# Epoch 73/100
#  - 37s - loss: 1.7645 - accuracy: 0.3785 - val_loss: 1.4969 - val_accuracy: 0.4517
#
# Epoch 00073: val_loss did not improve from 0.71527
# Epoch 74/100
#  - 35s - loss: 1.7708 - accuracy: 0.3733 - val_loss: 1.4822 - val_accuracy: 0.4306
#
# Epoch 00074: val_loss did not improve from 0.71527
# Epoch 75/100
#  - 32s - loss: 1.7811 - accuracy: 0.3695 - val_loss: 1.8926 - val_accuracy: 0.3692
#
# Epoch 00075: val_loss did not improve from 0.71527
# Epoch 76/100
#  - 28s - loss: 1.7836 - accuracy: 0.3677 - val_loss: 1.6498 - val_accuracy: 0.4267
#
# Epoch 00076: val_loss did not improve from 0.71527
# Epoch 77/100
#  - 32s - loss: 1.7749 - accuracy: 0.3747 - val_loss: 1.5625 - val_accuracy: 0.3849
#
# Epoch 00077: val_loss did not improve from 0.71527
# Epoch 78/100
#  - 31s - loss: 1.7676 - accuracy: 0.3722 - val_loss: 1.3370 - val_accuracy: 0.4263
#
# Epoch 00078: val_loss did not improve from 0.71527
# Epoch 79/100
#  - 30s - loss: 1.7681 - accuracy: 0.3717 - val_loss: 1.4166 - val_accuracy: 0.4720
#
# Epoch 00079: val_loss did not improve from 0.71527
# Epoch 80/100
#  - 30s - loss: 1.7618 - accuracy: 0.3685 - val_loss: 1.3546 - val_accuracy: 0.4551
#
# Epoch 00080: val_loss did not improve from 0.71527
# Epoch 81/100
#  - 30s - loss: 1.7761 - accuracy: 0.3655 - val_loss: 1.6552 - val_accuracy: 0.3843
#
# Epoch 00081: val_loss did not improve from 0.71527
# Epoch 82/100
#  - 33s - loss: 1.7952 - accuracy: 0.3604 - val_loss: 1.5346 - val_accuracy: 0.4300
#
# Epoch 00082: val_loss did not improve from 0.71527
# Epoch 83/100
#  - 31s - loss: 1.7763 - accuracy: 0.3660 - val_loss: 1.7601 - val_accuracy: 0.3818
#
# Epoch 00083: val_loss did not improve from 0.71527
# Epoch 84/100
#  - 35s - loss: 1.8037 - accuracy: 0.3534 - val_loss: 1.6689 - val_accuracy: 0.4064
#
# Epoch 00084: val_loss did not improve from 0.71527
# Epoch 85/100
#  - 32s - loss: 1.8043 - accuracy: 0.3480 - val_loss: 1.3956 - val_accuracy: 0.4130
#
# Epoch 00085: val_loss did not improve from 0.71527
# Epoch 86/100
#  - 31s - loss: 1.8354 - accuracy: 0.3430 - val_loss: 1.7709 - val_accuracy: 0.4428
#
# Epoch 00086: val_loss did not improve from 0.71527
# Epoch 87/100
#  - 33s - loss: 1.8549 - accuracy: 0.3443 - val_loss: 1.7087 - val_accuracy: 0.2848
#
# Epoch 00087: val_loss did not improve from 0.71527
# Epoch 88/100
#  - 38s - loss: 1.8406 - accuracy: 0.3345 - val_loss: 1.6354 - val_accuracy: 0.4155
#
# Epoch 00088: val_loss did not improve from 0.71527
# Epoch 89/100
#  - 42s - loss: 1.8334 - accuracy: 0.3380 - val_loss: 1.4290 - val_accuracy: 0.4213
#
# Epoch 00089: val_loss did not improve from 0.71527
# Epoch 90/100
#  - 42s - loss: 1.8369 - accuracy: 0.3332 - val_loss: 1.7608 - val_accuracy: 0.4096
#
# Epoch 00090: val_loss did not improve from 0.71527
# Epoch 91/100
#  - 45s - loss: 1.8537 - accuracy: 0.3279 - val_loss: 1.7641 - val_accuracy: 0.3492
#
# Epoch 00091: val_loss did not improve from 0.71527
# Epoch 92/100
#  - 36s - loss: 1.8547 - accuracy: 0.3254 - val_loss: 1.4375 - val_accuracy: 0.3829
#
# Epoch 00092: val_loss did not improve from 0.71527
# Epoch 93/100
#  - 35s - loss: 1.8401 - accuracy: 0.3275 - val_loss: 1.4882 - val_accuracy: 0.3581
#
# Epoch 00093: val_loss did not improve from 0.71527
# Epoch 94/100
#  - 32s - loss: 1.8552 - accuracy: 0.3248 - val_loss: 2.0336 - val_accuracy: 0.3176
#
# Epoch 00094: val_loss did not improve from 0.71527
# Epoch 95/100
#  - 34s - loss: 1.8567 - accuracy: 0.3213 - val_loss: 1.5264 - val_accuracy: 0.4010
#
# Epoch 00095: val_loss did not improve from 0.71527
# Epoch 96/100
#  - 31s - loss: 1.8763 - accuracy: 0.3199 - val_loss: 1.8027 - val_accuracy: 0.3784
#
# Epoch 00096: val_loss did not improve from 0.71527
# Epoch 97/100
#  - 30s - loss: 1.8815 - accuracy: 0.3135 - val_loss: 1.5954 - val_accuracy: 0.3490
#
# Epoch 00097: val_loss did not improve from 0.71527
# Epoch 98/100
#  - 30s - loss: 1.8691 - accuracy: 0.3180 - val_loss: 2.5761 - val_accuracy: 0.2836
#
# Epoch 00098: val_loss did not improve from 0.71527
# Epoch 99/100
#  - 31s - loss: 1.8818 - accuracy: 0.3100 - val_loss: 1.4779 - val_accuracy: 0.3764
#
# Epoch 00099: val_loss did not improve from 0.71527
# Epoch 100/100
#  - 34s - loss: 1.8631 - accuracy: 0.3181 - val_loss: 1.8560 - val_accuracy: 0.3454
#
# Epoch 00100: val_loss did not improve from 0.71527

# %% [markdown]
# ### 10. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('aug_model.weights.best.hdf5')

# %% [markdown]
# ### 11. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
# ('\n', 'Test accuracy:', 0.6168000102043152)

# %%
from keras.preprocessing.image import ImageDataGenerator

# create and configure augmented image generator
datagen_train = ImageDataGenerator(
    width_shift_range=0.1,  # randomly shift images horizontally (10% of total width)
    height_shift_range=0.1,  # randomly shift images vertically (10% of total height)
    horizontal_flip=True) # randomly flip images horizontally

# create and configure augmented image generator
datagen_valid = ImageDataGenerator(
    width_shift_range=0.1,  # randomly shift images horizontally (10% of total width)
    height_shift_range=0.1,  # randomly shift images vertically (10% of total height)
    horizontal_flip=True) # randomly flip images horizontally

# fit augmented image generator on data
datagen_train.fit(x_train)
datagen_valid.fit(x_valid)

import matplotlib.pyplot as plt

# take subset of training data
x_train_subset = x_train[:12]

# visualize subset of training data
fig = plt.figure(figsize=(20,2))
for i in range(0, len(x_train_subset)):
    ax = fig.add_subplot(1, 12, i+1)
    ax.imshow(x_train_subset[i])
fig.suptitle('Subset of Original Training Images', fontsize=20)
plt.show()

# visualize augmented images
fig = plt.figure(figsize=(20,2))
for x_batch in datagen_train.flow(x_train_subset, batch_size=12):
    for i in range(0, 12):
        ax = fig.add_subplot(1, 12, i+1)
        ax.imshow(x_batch[i])
    fig.suptitle('Augmented Images', fontsize=20)
    plt.show()
    break;
    
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

model.summary()
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])

from keras.callbacks import ModelCheckpoint   

batch_size = 32
epochs = 100

# train the model
checkpointer = ModelCheckpoint(filepath='aug_model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
model.fit_generator(datagen_train.flow(x_train, y_train, batch_size=batch_size),
                    steps_per_epoch=x_train.shape[0] // batch_size,
                    epochs=epochs, verbose=2, callbacks=[checkpointer],
                    validation_data=datagen_valid.flow(x_valid, y_valid, batch_size=batch_size),
                    validation_steps=x_valid.shape[0] // batch_size)

# load the weights that yielded the best validation accuracy
model.load_weights('aug_model.weights.best.hdf5')

# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 32, 32, 16)        208
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 500)               512500
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 528,054
# Trainable params: 528,054
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100

# %%
from keras.preprocessing.image import ImageDataGenerator

# create and configure augmented image generator
datagen_train = ImageDataGenerator(
    width_shift_range=0.1,  # randomly shift images horizontally (10% of total width)
    height_shift_range=0.1,  # randomly shift images vertically (10% of total height)
    horizontal_flip=True) # randomly flip images horizontally

# create and configure augmented image generator
datagen_valid = ImageDataGenerator(
    width_shift_range=0.1,  # randomly shift images horizontally (10% of total width)
    height_shift_range=0.1,  # randomly shift images vertically (10% of total height)
    horizontal_flip=True) # randomly flip images horizontally

# fit augmented image generator on data
datagen_train.fit(x_train)
datagen_valid.fit(x_valid)

import matplotlib.pyplot as plt

# take subset of training data
x_train_subset = x_train[:12]

# visualize subset of training data
fig = plt.figure(figsize=(20,2))
for i in range(0, len(x_train_subset)):
    ax = fig.add_subplot(1, 12, i+1)
    ax.imshow(x_train_subset[i])
fig.suptitle('Subset of Original Training Images', fontsize=20)
plt.show()

# visualize augmented images
fig = plt.figure(figsize=(20,2))
for x_batch in datagen_train.flow(x_train_subset, batch_size=12):
    for i in range(0, 12):
        ax = fig.add_subplot(1, 12, i+1)
        ax.imshow(x_batch[i])
    fig.suptitle('Augmented Images', fontsize=20)
    plt.show()
    break;
    
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

model.summary()
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])

from keras.callbacks import ModelCheckpoint   

batch_size = 32
epochs = 100

# train the model
checkpointer = ModelCheckpoint(filepath='aug_model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
model.fit_generator(datagen_train.flow(x_train, y_train, batch_size=batch_size),
                    steps_per_epoch=x_train.shape[0] // batch_size,
                    epochs=epochs, verbose=2, callbacks=[checkpointer],
                    validation_data=datagen_valid.flow(x_valid, y_valid, batch_size=batch_size),
                    validation_steps=x_valid.shape[0] // batch_size)

# load the weights that yielded the best validation accuracy
model.load_weights('aug_model.weights.best.hdf5')

# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])

# %%
from keras.preprocessing.image import ImageDataGenerator

# create and configure augmented image generator
datagen_train = ImageDataGenerator(
    width_shift_range=0.2,  # randomly shift images horizontally (10% of total width)
    height_shift_range=0.2,  # randomly shift images vertically (10% of total height)
    horizontal_flip=True) # randomly flip images horizontally

# create and configure augmented image generator
datagen_valid = ImageDataGenerator(
    width_shift_range=0.2,  # randomly shift images horizontally (10% of total width)
    height_shift_range=0.2,  # randomly shift images vertically (10% of total height)
    horizontal_flip=True) # randomly flip images horizontally

# fit augmented image generator on data
datagen_train.fit(x_train)
datagen_valid.fit(x_valid)

import matplotlib.pyplot as plt

# take subset of training data
x_train_subset = x_train[:12]

# visualize subset of training data
fig = plt.figure(figsize=(20,2))
for i in range(0, len(x_train_subset)):
    ax = fig.add_subplot(1, 12, i+1)
    ax.imshow(x_train_subset[i])
fig.suptitle('Subset of Original Training Images', fontsize=20)
plt.show()

# visualize augmented images
fig = plt.figure(figsize=(20,2))
for x_batch in datagen_train.flow(x_train_subset, batch_size=12):
    for i in range(0, 12):
        ax = fig.add_subplot(1, 12, i+1)
        ax.imshow(x_batch[i])
    fig.suptitle('Augmented Images', fontsize=20)
    plt.show()
    break;
    
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

model.summary()
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])

from keras.callbacks import ModelCheckpoint   

batch_size = 32
epochs = 100

# train the model
checkpointer = ModelCheckpoint(filepath='aug_model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
model.fit_generator(datagen_train.flow(x_train, y_train, batch_size=batch_size),
                    steps_per_epoch=x_train.shape[0] // batch_size,
                    epochs=epochs, verbose=2, callbacks=[checkpointer],
                    validation_data=datagen_valid.flow(x_valid, y_valid, batch_size=batch_size),
                    validation_steps=x_valid.shape[0] // batch_size)

# load the weights that yielded the best validation accuracy
model.load_weights('aug_model.weights.best.hdf5')

# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])

# %%
from keras.preprocessing.image import ImageDataGenerator

# create and configure augmented image generator
datagen_train = ImageDataGenerator(
     featurewise_center=True,
    featurewise_std_normalization=True,
    width_shift_range=0.1,  # randomly shift images horizontally (10% of total width)
    height_shift_range=0.1,  # randomly shift images vertically (10% of total height)
    horizontal_flip=True) # randomly flip images horizontally

# create and configure augmented image generator
datagen_valid = ImageDataGenerator(
     featurewise_center=True,
    featurewise_std_normalization=True,
    width_shift_range=0.1,  # randomly shift images horizontally (10% of total width)
    height_shift_range=0.1,  # randomly shift images vertically (10% of total height)
    horizontal_flip=True) # randomly flip images horizontally

# fit augmented image generator on data
datagen_train.fit(x_train)
datagen_valid.fit(x_valid)

import matplotlib.pyplot as plt

# take subset of training data
x_train_subset = x_train[:12]

# visualize subset of training data
fig = plt.figure(figsize=(20,2))
for i in range(0, len(x_train_subset)):
    ax = fig.add_subplot(1, 12, i+1)
    ax.imshow(x_train_subset[i])
fig.suptitle('Subset of Original Training Images', fontsize=20)
plt.show()

# visualize augmented images
fig = plt.figure(figsize=(20,2))
for x_batch in datagen_train.flow(x_train_subset, batch_size=12):
    for i in range(0, 12):
        ax = fig.add_subplot(1, 12, i+1)
        ax.imshow(x_batch[i])
    fig.suptitle('Augmented Images', fontsize=20)
    plt.show()
    break;
    
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

model.summary()
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])

from keras.callbacks import ModelCheckpoint   

batch_size = 32
epochs = 100

# train the model
checkpointer = ModelCheckpoint(filepath='aug_model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
model.fit_generator(datagen_train.flow(x_train, y_train, batch_size=batch_size),
                    steps_per_epoch=x_train.shape[0] // batch_size,
                    epochs=epochs, verbose=2, callbacks=[checkpointer],
                    validation_data=datagen_valid.flow(x_valid, y_valid, batch_size=batch_size),
                    validation_steps=x_valid.shape[0] // batch_size)

# load the weights that yielded the best validation accuracy
model.load_weights('aug_model.weights.best.hdf5')

# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
